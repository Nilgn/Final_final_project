# %% [markdown]
# # Data cleaning

# %%
import numpy as np
import pandas as pd
import datetime
from datetime import datetime

# %%
All_Matches = pd.read_csv('All Matches.csv')
National_Team_Appearance = pd.read_csv('National Teams Appearance.csv')
Participated_teams_general_statistics = pd.read_csv('Participated Teams General Statistics.csv')
Top_Goal_Scorers = pd.read_csv('Top Goal Scorers.csv')

# %%
All_Matches_df = pd.DataFrame(All_Matches)
National_Team_Appearance_df = pd.DataFrame(National_Team_Appearance)
Participated_teams_general_statistics_df = pd.DataFrame(Participated_teams_general_statistics)
Top_Goal_Scorers_df = pd.DataFrame(Top_Goal_Scorers)

# %%
All_Matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286 entries, 0 to 285
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  286 non-null    object
#  1   HomeTeamName          286 non-null    object
#  2   AwayTeamName          286 non-null    object
#  3   HomeTeamGoals         286 non-null    int64
#  4   AwayTeamGoals         286 non-null    int64
#  5   Stage                 286 non-null    object
#  6   SpecialWinConditions  33 non-null     object
#  7   Stadium               286 non-null    object
#  8   City                  286 non-null    object
#  9   Country               286 non-null    object
#  10  Attendance            286 non-null    int64
#  11  Year                  286 non-null    int64
# dtypes: int64(4), object(8)
# memory usage: 26.9+ KB

# %%
National_Team_Appearance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Team           35 non-null     object
#  1   Appearances    35 non-null     int64
#  2   Record streak  35 non-null     int64
#  3   Active streak  35 non-null     int64
#  4   Debut          35 non-null     int64
#  5   Most recent    35 non-null     int64
#  6   Best result    35 non-null     object
# dtypes: int64(5), object(2)
# memory usage: 2.0+ KB

# %%
Participated_teams_general_statistics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Team             33 non-null     object
#  1   Participations   33 non-null     int64
#  2   Played           33 non-null     int64
#  3   Win              33 non-null     int64
#  4   Draw             33 non-null     int64
#  5   Loss             33 non-null     int64
#  6   Goal_For         33 non-null     int64
#  7   Goal_Against     33 non-null     int64
#  8   Goal_Difference  33 non-null     object
#  9   Points           33 non-null     int64
#  10  Points/match     33 non-null     float64
# dtypes: float64(1), int64(8), object(2)
# memory usage: 3.0+ KB

# %%
Top_Goal_Scorers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Player          17 non-null     object
#  1   Team            17 non-null     object
#  2   Goals scored    17 non-null     int64
#  3   Matches played  17 non-null     int64
#  4   Goals average   17 non-null     float64
#  5   Tournament(s)   17 non-null     object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 944.0+ bytes

# %%
All_Matches_df.isna().sum()
# Out:
# Date                      0
# HomeTeamName              0
# AwayTeamName              0
# HomeTeamGoals             0
# AwayTeamGoals             0
# Stage                     0
# SpecialWinConditions    253
# Stadium                   0
# City                      0
# Country                   0
# Attendance                0
# Year                      0
# dtype: int64

# %%
National_Team_Appearance_df.isna().sum()
# Out:
# Team             0
# Appearances      0
# Record streak    0
# Active streak    0
# Debut            0
# Most recent      0
# Best result      0
# dtype: int64

# %%
Participated_teams_general_statistics_df.isna().sum()
# Out:
# Team               0
# Participations     0
# Played             0
# Win                0
# Draw               0
# Loss               0
# Goal_For           0
# Goal_Against       0
# Goal_Difference    0
# Points             0
# Points/match       0
# dtype: int64

# %%
Top_Goal_Scorers_df.isna().sum()
# Out:
# Player            0
# Team              0
# Goals scored      0
# Matches played    0
# Goals average     0
# Tournament(s)     0
# dtype: int64

# %%
All_Matches_df.describe()
# Out:
#        HomeTeamGoals  AwayTeamGoals    Attendance         Year
# count     286.000000     286.000000    286.000000   286.000000
# mean        1.293706       1.108392  40220.321678  1999.804196
# std         1.180735       1.045693  15744.718423    13.915665
# min         0.000000       0.000000   1659.000000  1960.000000
# 25%         0.000000       0.000000  29220.000000  1992.000000
# 50%         1.000000       1.000000  38746.500000  2004.000000
# 75%         2.000000       2.000000  50489.000000  2012.000000
# max         6.000000       5.000000  79115.000000  2016.000000

# %%
National_Team_Appearance_df.describe()
# Out:
#        Appearances  Record streak  Active streak        Debut  Most recent
# count    35.000000      35.000000      35.000000    35.000000    35.000000
# mean      5.142857       3.514286       2.685714  1989.828571  2016.571429
# std       3.750630       2.852980       3.113268    20.633334     6.518236
# min       1.000000       1.000000       0.000000  1960.000000  2000.000000
# 25%       2.000000       1.000000       0.000000  1970.000000  2016.000000
# 50%       4.000000       2.000000       2.000000  1992.000000  2020.000000
# 75%       8.500000       5.500000       4.500000  2008.000000  2020.000000
# max      13.000000      13.000000      13.000000  2020.000000  2020.000000

# %%
Participated_teams_general_statistics_df.describe()
# Out:
#        Participations     Played        Win       Draw       Loss   Goal_For  \
# count       33.000000  33.000000  33.000000  33.000000  33.000000  33.000000
# mean         4.727273  17.333333   6.454545   4.424242   6.454545  20.818182
# std          3.448485  13.667175   7.133070   4.092908   3.929781  20.708474
# min          1.000000   3.000000   0.000000   0.000000   1.000000   1.000000
# 25%          2.000000   6.000000   1.000000   1.000000   3.000000   4.000000
# 50%          4.000000  14.000000   3.000000   2.000000   6.000000  11.000000
# 75%          8.000000  31.000000  10.000000   6.000000  10.000000  38.000000
# max         12.000000  49.000000  26.000000  16.000000  14.000000  72.000000
#
#        Goal_Against     Points  Points/match
# count     33.000000  33.000000     33.000000
# mean      20.818182  23.787879      1.150303
# std       14.816491  24.932105      0.460689
# min        1.000000   1.000000      0.330000
# 25%        7.000000   4.000000      0.800000
# ...

# %%
Top_Goal_Scorers_df.describe()
# Out:
#        Goals scored  Matches played  Goals average
# count     17.000000       17.000000      17.000000
# mean       6.000000       10.823529       0.652353
# std        1.274755        4.003675       0.375009
# min        5.000000        4.000000       0.360000
# 25%        5.000000        9.000000       0.430000
# 50%        6.000000       11.000000       0.550000
# 75%        6.000000       13.000000       0.750000
# max        9.000000       21.000000       1.800000

# %%
Top_Goal_Scorers_df.iloc[0,0]
# Out:
# 'Michel Platini'

# %%
National_Team_Appearance_df.iloc[0,0]
# Out:
# 'Germany'

# %%
Participated_teams_general_statistics_df.iloc[0,0]
# Out:
# 'Germany'

# %%
Participated_teams_general_statistics_df.iloc[0,0]
# Out:
# 'Germany'

# %%
Top_Goal_Scorers_df.iloc[1,0]
# Out:
# 'Cristiano Ronaldo'

# %%
National_Team_Appearance_df.iloc[2,0]
# Out:
# 'Spain'

# %%
Participated_teams_general_statistics_df.iloc[4,0]
# Out:
# 'Portugal'

# %%
Participated_teams_general_statistics_df.iloc[5,0]
# Out:
# 'Netherlands'

# %%
Participated_teams_general_statistics_df.iloc[6,0]
# Out:
# 'Czech Republic'

# %%
Participated_teams_general_statistics_df.iloc[7,0]
# Out:
# 'Russia'

# %%
Participated_teams_general_statistics_df.iloc[8,0]
# Out:
# 'England'

# %%
Participated_teams_general_statistics_df.iloc[9,0]
# Out:
# 'Croatia'

# %%
Participated_teams_general_statistics_df.iloc[10,0]
# Out:
# 'Denmark'

# %%
Participated_teams_general_statistics_df.iloc[11,0]
# Out:
# 'Belgium'

# %%
np.random.randint(10,size=(3,2))
# Out:
# array([[2, 7],
#        [9, 1],
#        [6, 1]])

# %%
National_Team_Appearance_df.count()
# Out:
# Team             35
# Appearances      35
# Record streak    35
# Active streak    35
# Debut            35
# Most recent      35
# Best result      35
# dtype: int64

# %%
Participated_teams_general_statistics_df.count()
# Out:
# Team               33
# Participations     33
# Played             33
# Win                33
# Draw               33
# Loss               33
# Goal_For           33
# Goal_Against       33
# Goal_Difference    33
# Points             33
# Points/match       33
# dtype: int64

# %%
Top_Goal_Scorers_df.count()
# Out:
# Player            17
# Team              17
# Goals scored      17
# Matches played    17
# Goals average     17
# Tournament(s)     17
# dtype: int64

# %%
All_Matches_df.count()
# Out:
# Date                    286
# HomeTeamName            286
# AwayTeamName            286
# HomeTeamGoals           286
# AwayTeamGoals           286
# Stage                   286
# SpecialWinConditions     33
# Stadium                 286
# City                    286
# Country                 286
# Attendance              286
# Year                    286
# dtype: int64

# %%
All_Matches_df.mean()
# Out:
# /var/folders/8w/ffbmg1l958n0dtswfb_xw04c0000gn/T/ipykernel_42296/612391447.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   All_Matches_df.mean()
# HomeTeamGoals        1.293706
# AwayTeamGoals        1.108392
# Attendance       40220.321678
# Year              1999.804196
# dtype: float64

# %%
Top_Goal_Scorers_df.mean()
# Out:
# /var/folders/8w/ffbmg1l958n0dtswfb_xw04c0000gn/T/ipykernel_42296/3898854769.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Top_Goal_Scorers_df.mean()
# Goals scored       6.000000
# Matches played    10.823529
# Goals average      0.652353
# dtype: float64

# %%
Participated_teams_general_statistics_df.mean()
# Out:
# /var/folders/8w/ffbmg1l958n0dtswfb_xw04c0000gn/T/ipykernel_42296/2010241601.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Participated_teams_general_statistics_df.mean()
# Participations     4.727273
# Played            17.333333
# Win                6.454545
# Draw               4.424242
# Loss               6.454545
# Goal_For          20.818182
# Goal_Against      20.818182
# Points            23.787879
# Points/match       1.150303
# dtype: float64

# %%
National_Team_Appearance_df.mean()
# Out:
# /var/folders/8w/ffbmg1l958n0dtswfb_xw04c0000gn/T/ipykernel_42296/2762591799.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   National_Team_Appearance_df.mean()
# Appearances         5.142857
# Record streak       3.514286
# Active streak       2.685714
# Debut            1989.828571
# Most recent      2016.571429
# dtype: float64

# %%
National_Team_Appearance_df
# Out:
#                    Team  Appearances  Record streak  Active streak  Debut  \
# 0               Germany           13             13             13   1972
# 1                Russia           12              5              5   1960
# 2                 Spain           11              7              7   1964
# 3                France           10              8              8   1960
# 4                 Italy           10              7              7   1968
# 5        Czech Republic           10              7              7   1960
# 6           Netherlands           10              7              1   1976
# 7               England           10              5              3   1968
# 8               Denmark            9              6              1   1964
# 9              Portugal            8              7              7   1984
# 10               Sweden            7              6              6   1992
# 11              Belgium            6              2              2   1972
# ...

# %%
National_Team_Appearance_df = National_Team_Appearance_df.drop(columns = ['Appearances', 'Record streak', 'Active streak', 'Debut', 'Most recent'])

# %%
National_Team_Appearance_df
# Out:
#                    Team                              Best result
# 0               Germany             Champions (1972, 1980, 1996)
# 1                Russia                         Champions (1960)
# 2                 Spain            Champions (1964*, 2008, 2012)
# 3                France                  Champions (1984*, 2000)
# 4                 Italy                        Champions (1968*)
# 5        Czech Republic                         Champions (1976)
# 6           Netherlands                         Champions (1988)
# 7               England  Third place (1968), Semi-finals (1996*)
# 8               Denmark                         Champions (1992)
# 9              Portugal                         Champions (2016)
# 10               Sweden                      Semi-finals (1992*)
# 11              Belgium                        Runners-up (1980)
# 12              Croatia              Quarter-finals (1996, 2008)
# ...

# %%
National_Team_Appearance_df.dropna(inplace=True)

# %%
National_Team_Appearance_df
# Out:
#                    Team                              Best result
# 0               Germany             Champions (1972, 1980, 1996)
# 1                Russia                         Champions (1960)
# 2                 Spain            Champions (1964*, 2008, 2012)
# 3                France                  Champions (1984*, 2000)
# 4                 Italy                        Champions (1968*)
# 5        Czech Republic                         Champions (1976)
# 6           Netherlands                         Champions (1988)
# 7               England  Third place (1968), Semi-finals (1996*)
# 8               Denmark                         Champions (1992)
# 9              Portugal                         Champions (2016)
# 10               Sweden                      Semi-finals (1992*)
# 11              Belgium                        Runners-up (1980)
# 12              Croatia              Quarter-finals (1996, 2008)
# ...

# %%
Participated_teams_general_statistics_df
# Out:
#                    Team  Participations  Played  Win  Draw  Loss  Goal_For  \
# 0               Germany              12      49   26    12    11        72
# 1                France               9      39   20     9    10        62
# 2                 Spain              10      40   19    11    10        55
# 3                 Italy               9      38   16    16     6        39
# 4              Portugal               7      35   18     9     8        49
# 5           Netherlands               9      35   17     8    10        57
# 6        Czech Republic               9      32   13     6    13        42
# 7                Russia              11      33   12     7    14        38
# 8               England               9      31   10    11    10        40
# 9               Croatia               5      18    8     5     5        23
# 10              Denmark               8      27    7     6    14        30
# ...

# %%
Participated_teams_general_statistics_df = Participated_teams_general_statistics_df.drop(columns = ['Goal_For', 'Goal_Against', 'Goal_Difference'])

# %%
Participated_teams_general_statistics_df
# Out:
#                    Team  Participations  Played  Win  Draw  Loss  Points  \
# 0               Germany              12      49   26    12    11      90
# 1                France               9      39   20     9    10      69
# 2                 Spain              10      40   19    11    10      68
# 3                 Italy               9      38   16    16     6      64
# 4              Portugal               7      35   18     9     8      63
# 5           Netherlands               9      35   17     8    10      59
# 6        Czech Republic               9      32   13     6    13      45
# 7                Russia              11      33   12     7    14      43
# 8               England               9      31   10    11    10      41
# 9               Croatia               5      18    8     5     5      29
# 10              Denmark               8      27    7     6    14      27
# 11              Belgium               5      17    7     2     8      23
# ...

# %%
Top_Goal_Scorers_df
# Out:
#                  Player            Team  Goals scored  Matches played  \
# 0        Michel Platini          France             9               5
# 1     Cristiano Ronaldo        Portugal             9              21
# 2          Alan Shearer         England             7               9
# 3     Antoine Griezmann          France             6               7
# 4   Ruud van Nistelrooy     Netherlands             6               8
# 5      Patrick Kluivert     Netherlands             6               9
# 6          Wayne Rooney         England             6              10
# 7         Thierry Henry          France             6              11
# 8    Zlatan Ibrahimović          Sweden             6              13
# 9            Nuno Gomes        Portugal             6              14
# 10       Savo Milošević   FR Yugoslavia             5               4
# 11     Marco van Basten     Netherlands             5               9
# ...

# %%
All_Matches_df
# Out:
#            Date    HomeTeamName  AwayTeamName  HomeTeamGoals  AwayTeamGoals  \
# 0    1960-07-06          France    Yugoslavia              4              5
# 1    1960-07-06  Czechoslovakia  Soviet Union              0              3
# 2    1960-07-09  Czechoslovakia        France              2              0
# 3    1960-07-10    Soviet Union    Yugoslavia              2              1
# 4    1964-06-17           Spain       Hungary              2              1
# ..          ...             ...           ...            ...            ...
# 281  2016-07-02         Germany         Italy              1              1
# 282  2016-07-03          France       Iceland              5              2
# 283  2016-07-06        Portugal         Wales              2              0
# 284  2016-07-07         Germany        France              0              2
# 285  2016-07-10        Portugal        France              1              0
#
# ...

# %%
All_Matches_df = All_Matches_df.drop(columns = ['Attendance', 'SpecialWinConditions', 'Date', 'Stadium'])

# %%
All_Matches_df
# Out:
#        HomeTeamName  AwayTeamName  HomeTeamGoals  AwayTeamGoals  \
# 0            France    Yugoslavia              4              5
# 1    Czechoslovakia  Soviet Union              0              3
# 2    Czechoslovakia        France              2              0
# 3      Soviet Union    Yugoslavia              2              1
# 4             Spain       Hungary              2              1
# ..              ...           ...            ...            ...
# 281         Germany         Italy              1              1
# 282          France       Iceland              5              2
# 283        Portugal         Wales              2              0
# 284         Germany        France              0              2
# 285        Portugal        France              1              0
#
#                     Stage              City Country  Year
# 0             Semi-finals             Paris  France  1960
# 1             Semi-finals         Marseille  France  1960
# ...

# %%
All_Matches_df.to_csv('All_Matches_df.csv')
Top_Goal_Scorers_df.to_csv('Top_Goal_Scorers_df.csv')
Participated_teams_general_statistics_df.to_csv('Participated_teams_general_statistics_df.csv')
National_Team_Appearance_df.to_csv('National_Team_Appearance_df.csv')
